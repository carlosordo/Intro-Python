# %%
### Importar las librerias necesarias
import pandas as pd

# %% [markdown]
# # 1. Lectura de archivos

# %%
### Fuentes usuales csv, excel, bases de datos sql
df = pd.read_csv('archivos/auto.csv')
### lectura del archivo excel 
# df = pd.read_excel('')

# %%
### lectura de un archivo en un portal de github
#df = pd.read_csv('https://raw.githubusercontent.com/carlosordo/Intro-Python/refs/heads/main/Clase%201/archivos/auto.csv')

# %%
## lectura de una tabla en una base de datos usando pyodbc

# %%
### Fuentes no tan usuales json, parquet...

# %% [markdown]
# # 2. Visualizacion general de las tablas

# %%
### Nombres de las columnas
Names = ["symboling","normalized-losses","make","fuel type","aspiration", "num-of-doors",
         "body-style", "drive wheels","engine-location","wheel-base", "length","width",
         "height","curb-weight","engine-type", "num-of-cylinders", "engine-size","fuel system",
         "bore","stroke","compression-ratio",
         "horsepower", "peak-rpm","city-mpg","highway-mpg","price"]
df.columns = Names

# %%
### Usando un print
print(df)
# Out:
#      symboling normalized-losses         make fuel type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df
# Out:
#      symboling normalized-losses         make fuel type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.head(5)
# Out:
#    symboling normalized-losses         make fuel type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df.tail(5)
# Out:
#      symboling normalized-losses   make fuel type aspiration num-of-doors  \
# 199         -1                95  volvo       gas        std         four
# 200         -1                95  volvo       gas      turbo         four
# 201         -1                95  volvo       gas        std         four
# 202         -1                95  volvo    diesel      turbo         four
# 203         -1                95  volvo       gas      turbo         four
#
#     body-style drive wheels engine-location  wheel-base  ...  engine-size  \
# 199      sedan          rwd           front       109.1  ...          141
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          173
# 202      sedan          rwd           front       109.1  ...          145
# 203      sedan          rwd           front       109.1  ...          141
#
#      fuel system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (204, 26)

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          204 non-null    int64
#  1   normalized-losses  204 non-null    object
#  2   make               204 non-null    object
#  3   fuel type          204 non-null    object
#  4   aspiration         204 non-null    object
#  5   num-of-doors       204 non-null    object
#  6   body-style         204 non-null    object
#  7   drive wheels       204 non-null    object
#  8   engine-location    204 non-null    object
#  9   wheel-base         204 non-null    float64
#  10  length             204 non-null    float64
#  11  width              204 non-null    float64
#  12  height             204 non-null    float64
#  13  curb-weight        204 non-null    int64
#  14  engine-type        204 non-null    object
#  15  num-of-cylinders   204 non-null    object
# ...

# %%
# valores unicos y cantidad de valores unicos

# %%
# distribucion de una columna

# %%
# distribucion de una columna numerica

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     0.823529   98.806373  174.075000   65.916667   53.749020
# std      1.239035    5.994144   12.362123    2.146716    2.424901
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.075000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.200000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   204.000000   204.000000         204.000000  204.000000   204.000000
# mean   2555.602941   126.892157          10.148137   25.240196    30.769608
# std     521.960820    41.744569           3.981000    6.551513     6.898337
# ...

# %% [markdown]
# # 3. Filtros y ordenamiento

# %%
### soltar una columna que no necesitamos

### quedarnos con las columnas que necesitamos


### df = pd.read_csv('archivos/auto.csv',columns =[])

# %%
### ordenar en funcion a una columna
df.sort_values(by =)

# %%
### ordenar una tabla en funcion de mas de una campo

# %%
### filtrar una tabla con una caracteristica
df[df[''].isnull()]

# %% [markdown]
# # 4. Creacion de nuevas columnas

# %%
### Generamos una nueva columna

# %%
### Hagamos una funcion considerando mas de una columna

### Generamos una columna con una condicion

# %% [markdown]
# # 5. Escritura de un nuevo archivo

# %%
df.to_csv('Salida.csv')
df.to_excel('Salida.xlsx')
